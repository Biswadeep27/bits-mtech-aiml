# %%
# %pip install --upgrade dbdemos

# %%
dbutils.library.restartPython()

# %%
import dbdemos
dbdemos.install('llm-rag-chatbot', use_current_cluster = True, warehouse_name = 'Pricing SQL WH Serverless 2', catalog='beepz_dissertation_draft', schema='bronze')
